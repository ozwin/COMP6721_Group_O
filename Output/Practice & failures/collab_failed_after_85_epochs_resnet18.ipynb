# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
from torchsummary import summary
import torchvision
import time
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/5-class.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')

picture = plt.imread('/content/5-class/preprocessed-cleaned-set/train/class-1/00056e9548477cda7a885bb423cb668c.jpg')
imageShow = plt.imshow(picture)

# %%
resnet18Model=models.resnet18(pretrained=False)
num_filters = resnet18Model.fc.in_features
num_classes = 5 
resnet18Model.fc = nn.Linear(num_filters,num_classes)
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameters(resnet18Model)
# summary(resnet18Model,input_size=(3,324,324))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
resnet18Model.to(device)
print("Device: {}".format(device))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet18Model.parameters(), lr=0.001,momentum=0.9)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=0.0001)
n_epochs = 100
# Out:
# Device: cuda:0

# %%
#import this file to train models and pass the  name of the datset
# extract zip files
# load the images and labels based on the dataset requested
# do the pre-processing , batch normalization , flip etc

# Transofrmations for preprocessedSnakeImages dataset
# Reference from https://www.youtube.com/watch?v=z3kB3ISIPAg&list=PL3Dh_99BJkCEhE7Ri8W6aijiEqm3ZoGRq&index=4
training_path = '/content/5-class/preprocessed-cleaned-set/train/'
test_path = '/content/5-class/preprocessed-cleaned-set/test'
val_path = '/content/5-class/preprocessed-cleaned-set/val'
def transformDS1( batchSize, inputSize):

    training_transforms = transforms.Compose([transforms.Resize((inputSize,inputSize)),transforms.ToTensor()])
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform = training_transforms)
    train_Loader = torch.utils.data.DataLoader(dataset = train_dataset,batch_size=batchSize,shuffle=False)
    mean, std = get_mean_std(train_Loader)
    train_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    test_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    val_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform=train_transforms)
    test_dataset = torchvision.datasets.ImageFolder(root=test_path,transform=test_transforms)
    val_dataset = torchvision.datasets.ImageFolder(root=val_path,transform=val_transforms)

    data_loader_train = torch.utils.data.DataLoader(train_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_test = torch.utils.data.DataLoader(test_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_val = torch.utils.data.DataLoader(val_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)

    return data_loader_train,data_loader_test,data_loader_val

def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

def show_transformed_images(data_loader_train):
    batch=next(iter(data_loader_train))
    images,labels = batch
    grid = torchvision.utils.make_grid(images,nrow=3)
    plt.figure(figsize=(11,11))
    plt.imshow(np.transpose(grid,(1,2,0)))
    plt.show()
    print("labels:",labels)

# %%
data_loader_train,data_loader_test,data_loader_val = transformDS1(32,224)
show_transformed_images(data_loader_val)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels: tensor([0, 4, 2, 4, 2, 3, 2, 0, 0, 1, 0, 0, 1, 1, 2, 0, 4, 0, 4, 0, 3, 1, 2, 3,
#         3, 3, 0, 3, 2, 0, 3, 4])

# %%
Accuracies=[]
valAccuracies = []
total_steps = len(data_loader_train)
t1 = time.time()
for epoch in range(n_epochs):
    print("Epoch number %d" %(epoch+1))
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    resnet18Model.to(device)
    print("Device: {}".format(device))
    resnet18Model.train()
    running_loss = 0.0
    running_correct = 0.0
    total = 0
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        total += labels.size(0)

        optimizer.zero_grad()
        outputs = resnet18Model(images)
        _,predicted = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_correct += (predicted == labels).sum().item()
        if (i + 1) % 100 == 0:
            validation_accuracy = 0
            resnet18Model.eval()
            with torch.no_grad(): 
                val_correct = 0
                val_total = 0
                for data in data_loader_val:
                    images, val_labels = data[0].to(device), data[1].to(device)
                    outputs = resnet18Model(images)

                    # Validation set accuracy
                    val_total = val_labels.size(0)
                    _,predicted = torch.max(outputs.data, 1)
                    val_correct += (predicted == val_labels).sum().item()
                    val_total  += val_labels.size(0)

            validation_accuracy = (val_correct / val_total)
            training_accuracy = (running_correct / total) * 100
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Training Accuracy: {:.2f}%, Validation Accuracy: {:.2f}%'
                .format(epoch + 1, n_epochs, i + 1, total_steps, loss.item(), training_accuracy , validation_accuracy))
    scheduler.step()
    epoch_loss = running_loss/len(data_loader_train)
    epoch_accuracy = 100.00 * (running_correct/total)   
    Accuracies.append(epoch_accuracy)
    valAccuracies.append(validation_accuracy)      
    print("Training Data: Epoch Loss: %.3f, Epoch Accuracy: %.3f"%(epoch_loss,epoch_accuracy))
      
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
torch.save(resnet18Model.state_dict(), "/content/5-class-d1-output.pt")
# Out:
# Epoch number 1
# Epoch [1/100], Step [100/381], Loss: 1.6131, Training Accuracy: 27.50%, Validation Accuracy: 26.30%
# Epoch [1/100], Step [200/381], Loss: 1.5495, Training Accuracy: 28.59%, Validation Accuracy: 26.30%
# Epoch [1/100], Step [300/381], Loss: 1.4450, Training Accuracy: 29.39%, Validation Accuracy: 25.88%
# Training Data: Epoch Loss: 1.552, Epoch Accuracy: 30.134
# Epoch number 2
# Epoch [2/100], Step [100/381], Loss: 1.2884, Training Accuracy: 38.75%, Validation Accuracy: 32.90%
# Epoch [2/100], Step [200/381], Loss: 1.5894, Training Accuracy: 36.12%, Validation Accuracy: 27.95%
# Epoch [2/100], Step [300/381], Loss: 1.3738, Training Accuracy: 35.04%, Validation Accuracy: 30.02%
# Training Data: Epoch Loss: 1.475, Epoch Accuracy: 35.237
# Epoch number 3
# Epoch [3/100], Step [100/381], Loss: 1.4657, Training Accuracy: 39.81%, Validation Accuracy: 36.05%
# Epoch number 39
# Epoch [39/100], Step [100/381], Loss: 0.6692, Training Accuracy: 75.34%, Validation Accuracy: 63.85%
# Epoch [39/100], Step [200/381], Loss: 0.4798, Training Accuracy: 74.70%, Validation Accuracy: 61.08%
# Epoch [39/100], Step [300/381], Loss: 0.7552, Training Accuracy: 74.82%, Validation Accuracy: 62.62%
# Training Data: Epoch Loss: 0.653, Epoch Accuracy: 75.010
# Epoch number 40
# Epoch [40/100], Step [100/381], Loss: 0.7062, Training Accuracy: 75.66%, Validation Accuracy: 64.80%
# Epoch [40/100], Step [200/381], Loss: 0.4396, Training Accuracy: 75.14%, Validation Accuracy: 61.67%
# Epoch [40/100], Step [300/381], Loss: 1.1140, Training Accuracy: 74.85%, Validation Accuracy: 64.08%
# Training Data: Epoch Loss: 0.647, Epoch Accuracy: 75.232
# Epoch number 41
# Epoch [41/100], Step [100/381], Loss: 0.6149, Training Accuracy: 75.72%, Validation Accuracy: 64.20%
# Epoch [41/100], Step [200/381], Loss: 0.3954, Training Accuracy: 75.59%, Validation Accuracy: 62.20%
# Epoch [41/100], Step [300/381], Loss: 0.6558, Training Accuracy: 75.01%, Validation Accuracy: 61.27%
# Training Data: Epoch Loss: 0.657, Epoch Accuracy: 74.936
# Epoch number 42
# Epoch [42/100], Step [100/381], Loss: 0.6822, Training Accuracy: 76.97%, Validation Accuracy: 65.20%
# Epoch [42/100], Step [200/381], Loss: 0.6179, Training Accuracy: 76.72%, Validation Accuracy: 63.45%
# Epoch [42/100], Step [300/381], Loss: 0.6888, Training Accuracy: 76.58%, Validation Accuracy: 59.35%
# Training Data: Epoch Loss: 0.635, Epoch Accuracy: 75.684
# Epoch number 43
# Epoch [43/100], Step [100/381], Loss: 0.8516, Training Accuracy: 77.00%, Validation Accuracy: 64.38%
# Epoch [43/100], Step [200/381], Loss: 0.7109, Training Accuracy: 75.98%, Validation Accuracy: 62.12%
# Epoch [43/100], Step [300/381], Loss: 0.5834, Training Accuracy: 75.94%, Validation Accuracy: 61.45%
# Training Data: Epoch Loss: 0.624, Epoch Accuracy: 76.095
# Epoch number 44
# Epoch [44/100], Step [100/381], Loss: 0.6081, Training Accuracy: 77.66%, Validation Accuracy: 64.95%
# Epoch [44/100], Step [200/381], Loss: 0.5007, Training Accuracy: 76.86%, Validation Accuracy: 62.95%
# Epoch [44/100], Step [300/381], Loss: 0.7195, Training Accuracy: 76.90%, Validation Accuracy: 62.42%
# Training Data: Epoch Loss: 0.619, Epoch Accuracy: 76.415
# Epoch number 45
# Epoch [45/100], Step [100/381], Loss: 0.5123, Training Accuracy: 78.31%, Validation Accuracy: 64.90%
# Epoch [45/100], Step [200/381], Loss: 0.6095, Training Accuracy: 77.67%, Validation Accuracy: 63.48%
# Epoch [45/100], Step [300/381], Loss: 0.9542, Training Accuracy: 77.23%, Validation Accuracy: 58.77%
# Training Data: Epoch Loss: 0.606, Epoch Accuracy: 76.958
# Epoch number 46
# Epoch [53/100], Step [200/381], Loss: 0.4623, Training Accuracy: 79.55%, Validation Accuracy: 65.92%
# Epoch [53/100], Step [300/381], Loss: 0.6612, Training Accuracy: 79.00%, Validation Accuracy: 64.88%
# Training Data: Epoch Loss: 0.540, Epoch Accuracy: 79.201
# Epoch number 54
# Epoch [54/100], Step [100/381], Loss: 0.4655, Training Accuracy: 78.97%, Validation Accuracy: 66.00%
# Epoch [54/100], Step [200/381], Loss: 0.5615, Training Accuracy: 80.11%, Validation Accuracy: 65.12%
# Epoch [54/100], Step [300/381], Loss: 0.5107, Training Accuracy: 80.33%, Validation Accuracy: 62.10%
# Training Data: Epoch Loss: 0.530, Epoch Accuracy: 80.031
# Epoch number 55
# Epoch [55/100], Step [100/381], Loss: 0.6018, Training Accuracy: 80.88%, Validation Accuracy: 66.85%
# Epoch [55/100], Step [200/381], Loss: 0.4919, Training Accuracy: 80.67%, Validation Accuracy: 63.40%
# Epoch [55/100], Step [300/381], Loss: 0.4189, Training Accuracy: 80.66%, Validation Accuracy: 66.03%
# Training Data: Epoch Loss: 0.507, Epoch Accuracy: 81.050
# Epoch number 56
# Epoch [56/100], Step [100/381], Loss: 0.2278, Training Accuracy: 82.09%, Validation Accuracy: 66.22%
# Epoch [56/100], Step [200/381], Loss: 0.5435, Training Accuracy: 81.88%, Validation Accuracy: 64.20%
# Epoch [56/100], Step [300/381], Loss: 0.8245, Training Accuracy: 81.08%, Validation Accuracy: 60.60%
# Training Data: Epoch Loss: 0.512, Epoch Accuracy: 81.132
# Epoch number 57
# Epoch [57/100], Step [100/381], Loss: 0.4076, Training Accuracy: 82.12%, Validation Accuracy: 67.10%
# Epoch [57/100], Step [200/381], Loss: 0.5918, Training Accuracy: 82.16%, Validation Accuracy: 61.70%
# Epoch [57/100], Step [300/381], Loss: 0.4400, Training Accuracy: 81.56%, Validation Accuracy: 65.03%
# Training Data: Epoch Loss: 0.499, Epoch Accuracy: 81.264
# Epoch number 58
# Epoch [58/100], Step [100/381], Loss: 0.2932, Training Accuracy: 81.72%, Validation Accuracy: 66.70%
# Epoch [58/100], Step [200/381], Loss: 0.4802, Training Accuracy: 81.47%, Validation Accuracy: 65.38%
# Epoch [58/100], Step [300/381], Loss: 0.3277, Training Accuracy: 81.52%, Validation Accuracy: 64.25%
# Training Data: Epoch Loss: 0.488, Epoch Accuracy: 81.502
# Epoch number 59
# Epoch [59/100], Step [100/381], Loss: 0.6287, Training Accuracy: 82.44%, Validation Accuracy: 66.55%
# Epoch [59/100], Step [200/381], Loss: 0.7452, Training Accuracy: 82.19%, Validation Accuracy: 64.88%
# Epoch [59/100], Step [300/381], Loss: 0.4033, Training Accuracy: 81.97%, Validation Accuracy: 62.83%
# Training Data: Epoch Loss: 0.491, Epoch Accuracy: 81.510
# Epoch number 60
# Epoch [60/100], Step [100/381], Loss: 0.5076, Training Accuracy: 80.69%, Validation Accuracy: 66.55%
# Epoch [60/100], Step [200/381], Loss: 0.3858, Training Accuracy: 81.64%, Validation Accuracy: 66.58%
# Epoch [60/100], Step [300/381], Loss: 0.4648, Training Accuracy: 82.11%, Validation Accuracy: 65.20%
# Training Data: Epoch Loss: 0.472, Epoch Accuracy: 82.308
# Epoch number 61
# Epoch [61/100], Step [100/381], Loss: 0.3176, Training Accuracy: 82.59%, Validation Accuracy: 66.85%
# Epoch [61/100], Step [200/381], Loss: 0.3866, Training Accuracy: 82.67%, Validation Accuracy: 66.03%
# Epoch [61/100], Step [300/381], Loss: 0.3852, Training Accuracy: 82.53%, Validation Accuracy: 66.40%
# Training Data: Epoch Loss: 0.466, Epoch Accuracy: 82.612
# Epoch number 62
# Epoch [62/100], Step [100/381], Loss: 0.7165, Training Accuracy: 83.59%, Validation Accuracy: 67.15%
# Epoch [62/100], Step [200/381], Loss: 0.4526, Training Accuracy: 83.36%, Validation Accuracy: 64.28%
# Epoch [62/100], Step [300/381], Loss: 0.5785, Training Accuracy: 82.99%, Validation Accuracy: 65.25%
# Training Data: Epoch Loss: 0.459, Epoch Accuracy: 82.948
# Epoch number 63
# Epoch [63/100], Step [100/381], Loss: 0.3185, Training Accuracy: 84.22%, Validation Accuracy: 67.10%
# Epoch [63/100], Step [200/381], Loss: 0.4810, Training Accuracy: 83.06%, Validation Accuracy: 66.10%
# Epoch [63/100], Step [300/381], Loss: 0.3908, Training Accuracy: 82.95%, Validation Accuracy: 64.80%
# Training Data: Epoch Loss: 0.448, Epoch Accuracy: 83.458
# Epoch number 64
# Epoch [64/100], Step [100/381], Loss: 0.4961, Training Accuracy: 84.44%, Validation Accuracy: 67.15%
# Epoch [64/100], Step [200/381], Loss: 0.2908, Training Accuracy: 84.59%, Validation Accuracy: 65.88%
# Epoch [64/100], Step [300/381], Loss: 0.6065, Training Accuracy: 84.27%, Validation Accuracy: 66.35%
# Training Data: Epoch Loss: 0.437, Epoch Accuracy: 83.721
# Epoch number 65
# Epoch [65/100], Step [100/381], Loss: 0.3747, Training Accuracy: 83.53%, Validation Accuracy: 67.62%
# Epoch [65/100], Step [200/381], Loss: 0.4828, Training Accuracy: 84.17%, Validation Accuracy: 66.60%
# Epoch [65/100], Step [300/381], Loss: 0.8061, Training Accuracy: 83.47%, Validation Accuracy: 64.33%
# Training Data: Epoch Loss: 0.440, Epoch Accuracy: 83.680
# Epoch number 66
# Epoch [66/100], Step [100/381], Loss: 0.4746, Training Accuracy: 84.69%, Validation Accuracy: 66.60%
# Epoch [66/100], Step [200/381], Loss: 0.5766, Training Accuracy: 84.70%, Validation Accuracy: 66.33%
# Epoch [66/100], Step [300/381], Loss: 0.3882, Training Accuracy: 84.34%, Validation Accuracy: 66.25%
# Training Data: Epoch Loss: 0.422, Epoch Accuracy: 84.469
# Epoch number 67
# Epoch [67/100], Step [100/381], Loss: 0.4812, Training Accuracy: 84.44%, Validation Accuracy: 67.60%
# Epoch [67/100], Step [200/381], Loss: 0.3486, Training Accuracy: 84.77%, Validation Accuracy: 63.55%
# Epoch [67/100], Step [300/381], Loss: 0.3510, Training Accuracy: 84.85%, Validation Accuracy: 64.65%
# Training Data: Epoch Loss: 0.416, Epoch Accuracy: 84.600
# Epoch number 68
# Epoch [68/100], Step [100/381], Loss: 0.4331, Training Accuracy: 84.94%, Validation Accuracy: 66.90%
# Epoch [68/100], Step [200/381], Loss: 0.5158, Training Accuracy: 84.97%, Validation Accuracy: 65.95%
# Epoch [68/100], Step [300/381], Loss: 0.2872, Training Accuracy: 85.41%, Validation Accuracy: 66.62%
# Training Data: Epoch Loss: 0.400, Epoch Accuracy: 85.364
# Epoch number 69
# Epoch [69/100], Step [100/381], Loss: 0.3629, Training Accuracy: 85.44%, Validation Accuracy: 66.60%
# Epoch [69/100], Step [200/381], Loss: 0.3125, Training Accuracy: 85.80%, Validation Accuracy: 66.08%
# Epoch [69/100], Step [300/381], Loss: 0.1380, Training Accuracy: 85.08%, Validation Accuracy: 65.75%
# Training Data: Epoch Loss: 0.400, Epoch Accuracy: 84.954
# Epoch number 70
# Epoch [70/100], Step [100/381], Loss: 0.2202, Training Accuracy: 85.22%, Validation Accuracy: 66.92%
# Epoch [70/100], Step [200/381], Loss: 0.4749, Training Accuracy: 85.33%, Validation Accuracy: 65.58%
# Epoch [70/100], Step [300/381], Loss: 0.3689, Training Accuracy: 85.47%, Validation Accuracy: 65.92%
# Training Data: Epoch Loss: 0.392, Epoch Accuracy: 85.693
# Epoch number 71
# Epoch [71/100], Step [100/381], Loss: 0.4627, Training Accuracy: 85.72%, Validation Accuracy: 67.58%
# Epoch [71/100], Step [200/381], Loss: 0.5007, Training Accuracy: 86.31%, Validation Accuracy: 64.53%
# Epoch [71/100], Step [300/381], Loss: 0.6508, Training Accuracy: 86.19%, Validation Accuracy: 67.05%
# Training Data: Epoch Loss: 0.377, Epoch Accuracy: 86.277
# Epoch number 72
# Epoch [72/100], Step [100/381], Loss: 0.4682, Training Accuracy: 85.53%, Validation Accuracy: 67.00%
# Epoch [72/100], Step [200/381], Loss: 0.3592, Training Accuracy: 85.88%, Validation Accuracy: 66.05%
# Epoch [72/100], Step [300/381], Loss: 0.4742, Training Accuracy: 85.95%, Validation Accuracy: 66.08%
# Training Data: Epoch Loss: 0.375, Epoch Accuracy: 85.948
# Epoch number 73
# Epoch [73/100], Step [100/381], Loss: 0.4510, Training Accuracy: 86.00%, Validation Accuracy: 67.80%
# Epoch [73/100], Step [200/381], Loss: 0.3679, Training Accuracy: 86.75%, Validation Accuracy: 67.20%
# Epoch [73/100], Step [300/381], Loss: 0.3468, Training Accuracy: 86.20%, Validation Accuracy: 63.05%
# Training Data: Epoch Loss: 0.376, Epoch Accuracy: 85.923
# Epoch number 74
# Epoch [74/100], Step [100/381], Loss: 0.6110, Training Accuracy: 85.75%, Validation Accuracy: 67.45%
# Epoch [74/100], Step [200/381], Loss: 0.5458, Training Accuracy: 86.45%, Validation Accuracy: 64.35%
# Epoch [74/100], Step [300/381], Loss: 0.4319, Training Accuracy: 86.52%, Validation Accuracy: 66.67%
# Training Data: Epoch Loss: 0.364, Epoch Accuracy: 86.614
# Epoch number 75
# Epoch [75/100], Step [100/381], Loss: 0.4909, Training Accuracy: 86.22%, Validation Accuracy: 67.55%
# Epoch [75/100], Step [200/381], Loss: 0.2896, Training Accuracy: 86.42%, Validation Accuracy: 64.20%
# Epoch [75/100], Step [300/381], Loss: 0.4595, Training Accuracy: 86.54%, Validation Accuracy: 66.47%
# Training Data: Epoch Loss: 0.361, Epoch Accuracy: 86.564
# Epoch number 76
# Epoch [76/100], Step [100/381], Loss: 0.3308, Training Accuracy: 85.41%, Validation Accuracy: 67.38%
# Epoch [76/100], Step [200/381], Loss: 0.3601, Training Accuracy: 86.08%, Validation Accuracy: 65.85%
# Epoch [76/100], Step [300/381], Loss: 0.3627, Training Accuracy: 86.05%, Validation Accuracy: 66.30%
# Training Data: Epoch Loss: 0.358, Epoch Accuracy: 86.441
# Epoch number 77
# Epoch [77/100], Step [100/381], Loss: 0.2266, Training Accuracy: 85.62%, Validation Accuracy: 67.12%
# Epoch [77/100], Step [200/381], Loss: 0.3795, Training Accuracy: 86.55%, Validation Accuracy: 67.35%
# Epoch [77/100], Step [300/381], Loss: 0.1450, Training Accuracy: 87.33%, Validation Accuracy: 67.58%
# Training Data: Epoch Loss: 0.343, Epoch Accuracy: 87.452
# Epoch number 78
# Epoch [78/100], Step [100/381], Loss: 0.3380, Training Accuracy: 86.47%, Validation Accuracy: 67.62%
# Epoch [78/100], Step [200/381], Loss: 0.2193, Training Accuracy: 87.52%, Validation Accuracy: 66.40%
# Epoch [78/100], Step [300/381], Loss: 0.3155, Training Accuracy: 87.68%, Validation Accuracy: 66.28%
# Training Data: Epoch Loss: 0.341, Epoch Accuracy: 87.748
# Epoch number 79
# Epoch [79/100], Step [100/381], Loss: 0.4349, Training Accuracy: 87.81%, Validation Accuracy: 67.33%
# Epoch [79/100], Step [200/381], Loss: 0.2417, Training Accuracy: 88.20%, Validation Accuracy: 67.45%
# Epoch [79/100], Step [300/381], Loss: 0.3678, Training Accuracy: 88.12%, Validation Accuracy: 65.97%
# Training Data: Epoch Loss: 0.329, Epoch Accuracy: 88.232
# Epoch number 80
# Epoch [80/100], Step [100/381], Loss: 0.4088, Training Accuracy: 85.44%, Validation Accuracy: 67.85%
# Epoch [80/100], Step [200/381], Loss: 0.5209, Training Accuracy: 87.14%, Validation Accuracy: 66.35%
# Epoch [80/100], Step [300/381], Loss: 0.4413, Training Accuracy: 87.55%, Validation Accuracy: 66.97%
# Training Data: Epoch Loss: 0.325, Epoch Accuracy: 87.731
# Epoch number 81
# Epoch [81/100], Step [100/381], Loss: 0.4741, Training Accuracy: 87.94%, Validation Accuracy: 67.55%
# Epoch [81/100], Step [200/381], Loss: 0.3919, Training Accuracy: 88.31%, Validation Accuracy: 64.88%
# Epoch [81/100], Step [300/381], Loss: 0.2693, Training Accuracy: 88.80%, Validation Accuracy: 67.08%
# Training Data: Epoch Loss: 0.317, Epoch Accuracy: 88.610
# Epoch number 82
# Epoch [82/100], Step [100/381], Loss: 0.4251, Training Accuracy: 87.53%, Validation Accuracy: 67.38%
# Epoch [82/100], Step [200/381], Loss: 0.3561, Training Accuracy: 88.55%, Validation Accuracy: 65.90%
# Epoch [82/100], Step [300/381], Loss: 0.3337, Training Accuracy: 89.03%, Validation Accuracy: 66.45%
# Training Data: Epoch Loss: 0.303, Epoch Accuracy: 89.177
# Epoch number 83
# Epoch [83/100], Step [100/381], Loss: 0.2561, Training Accuracy: 87.09%, Validation Accuracy: 67.40%
# Epoch [83/100], Step [200/381], Loss: 0.3056, Training Accuracy: 88.17%, Validation Accuracy: 67.12%
# Epoch [83/100], Step [300/381], Loss: 0.2147, Training Accuracy: 88.84%, Validation Accuracy: 67.22%
# Training Data: Epoch Loss: 0.311, Epoch Accuracy: 88.988
# Epoch number 84
# Epoch [84/100], Step [100/381], Loss: 0.2684, Training Accuracy: 87.12%, Validation Accuracy: 67.35%
# Epoch [84/100], Step [200/381], Loss: 0.1994, Training Accuracy: 88.48%, Validation Accuracy: 66.55%
# Epoch [84/100], Step [300/381], Loss: 0.3999, Training Accuracy: 89.26%, Validation Accuracy: 67.38%
# Training Data: Epoch Loss: 0.294, Epoch Accuracy: 89.506
# Epoch number 85

# %%
# print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
torch.save(resnet18Model.state_dict(), "/content/84-class-d1-output.pt")
resnet18Model.eval()
predicted_correct =0
total = 0
with torch.no_grad():
    for data in data_loader_test:
        images,labels = data
        images = images.to(device)
        labels = labels.to(device)
        total+=labels.size(0)
        outputs = resnet18Model(images)
        _,predicted = torch.max(outputs,1)
        predicted_correct += (predicted == labels).sum().item()
epoch_accuracy = 100.0* predicted_correct/total
print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
dict = {'Training': Accuracies, 'Validation': valAccuracies} 
df = pd.DataFrame(dict)
df.to_csv("/content/Accuracies.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-36071019fbeb> in <module>
#       1 # print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# ----> 2 torch.save(resnet18Model.state_dict(), "/content/84-class-d1-output.pt")
#       3 resnet18Model.eval()
#       4 predicted_correct =0
#       5 total = 0
#
# NameError: name 'torch' is not defined

# %%
# Plotting Accuracies Vs Epochs
plt.plot(range(n_epochs),Accuracies)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracies")
plt.title("Training Accuracy Vs Epochs")
plt.show()

# %%
# Plotting Validation Accuracies Vs Train Accuracies on Epochs
plt.plot(range(n_epochs),Accuracies, label="Training")
plt.plot(range(n_epochs),valAccuracies, label="Validation")
plt.xlable("Epochs")
plt.ylabel("Accuracies")
plt.title("Training vs Validation Accuracies")
plt.legend()
plt.show()

# %%
from torchvision.models.resnet import resnet34
#Calculate Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []

# iterate over test data
for data in data_loader_test:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = resnet34(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = ('0', '1', ' 2', ' 3', '4')

# Build confusion matrix
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),
                              display_labels=classes)
disp.plot()

plt.show()
