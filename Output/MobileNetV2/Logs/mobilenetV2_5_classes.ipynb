# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
from torchsummary import summary
import torchvision
import time
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import os
from google.colab import files
from google.colab import drive

# %%
drive.mount('/content/drive')
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/5-class.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')

picture = plt.imread('/content/5-class/preprocessed-cleaned-set/train/class-1/00056e9548477cda7a885bb423cb668c.jpg')
imageShow = plt.imshow(picture)
# Out:
# Mounted at /content/drive
# Done

# %%
mobilenetV2=models.mobilenet_v2(pretrained=False, num_classes = 5 )
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameters(mobilenetV2)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
mobilenetV2.to(device)
print("Device: {}".format(device))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(mobilenetV2.parameters(), lr=0.0002,momentum=0.9)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.0001)
n_epochs = 100
epoch_count = 0
# resnet18Model.load_state_dict(torch.load('/content/82-epoch-output.pt'))
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Device: cuda:0

# %%
#import this file to train models and pass the  name of the datset
# extract zip files
# load the images and labels based on the dataset requested
# do the pre-processing , batch normalization , flip etc

# Transofrmations for preprocessedSnakeImages dataset
# Reference from https://www.youtube.com/watch?v=z3kB3ISIPAg&list=PL3Dh_99BJkCEhE7Ri8W6aijiEqm3ZoGRq&index=4
training_path = '/content/5-class/preprocessed-cleaned-set/train/'
test_path = '/content/5-class/preprocessed-cleaned-set/test'
val_path = '/content/5-class/preprocessed-cleaned-set/val'
def transformDS1( batchSize, inputSize):

    training_transforms = transforms.Compose([transforms.Resize((inputSize,inputSize)),transforms.ToTensor()])
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform = training_transforms)
    train_Loader = torch.utils.data.DataLoader(dataset = train_dataset,batch_size=batchSize,shuffle=False)
    mean, std = get_mean_std(train_Loader)
    train_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    test_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    val_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform=train_transforms)
    test_dataset = torchvision.datasets.ImageFolder(root=test_path,transform=test_transforms)
    val_dataset = torchvision.datasets.ImageFolder(root=val_path,transform=val_transforms)

    data_loader_train = torch.utils.data.DataLoader(train_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_test = torch.utils.data.DataLoader(test_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_val = torch.utils.data.DataLoader(val_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)

    return data_loader_train,data_loader_test,data_loader_val

def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

def show_transformed_images(data_loader_train):
    batch=next(iter(data_loader_train))
    images,labels = batch
    grid = torchvision.utils.make_grid(images,nrow=3)
    plt.figure(figsize=(11,11))
    plt.imshow(np.transpose(grid,(1,2,0)))
    plt.show()
    print("labels:",labels)

# %%
def evaluate_model(model,test_loader):
    model.eval()
    predicted_correct =0
    total = 0
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total+=labels.size(0)
            outputs = model(images)
            _,predicted = torch.max(outputs,1)
            predicted_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100.0* predicted_correct/total
    print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
    return epoch_accuracy

# %%
train_loader,test_loader,val_loader = transformDS1(32,224)
show_transformed_images(val_loader)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels: tensor([4, 4, 1, 2, 1, 2, 1, 2, 2, 3, 2, 2, 3, 0, 2, 0, 0, 0, 2, 3, 0, 4, 2, 2,
#         0, 4, 4, 2, 4, 1, 1, 1])

# %%
Accuracies = [] 
valAccuracies = []
valLoss = []
trainLoss = []
total_steps = len(train_loader)
t1 = time.time()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
validation_accuracy = 0
for epoch in range(n_epochs):
    print("Epoch number %d" %(epoch+1))
    mobilenetV2.train()
    running_loss = 0.0
    running_correct = 0.0
    val_loss = 0.0
    total = 0
    for i, data in enumerate(train_loader):
      images,labels = data
      device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
      images = images.to(device)
      labels = labels.to(device)
      total+=labels.size(0)

      optimizer.zero_grad()
      outputs = mobilenetV2(images)
      _,predicted = torch.max(outputs.data,1)
      loss = criterion(outputs,labels)
      loss.backward()
      optimizer.step()
      
      running_loss+=loss.item()
      running_correct += (labels==predicted).sum().item()
     
      
      training_accuracy = (running_correct / total) * 100
    validation_accuracy = 0
    mobilenetV2.eval()
    with torch.no_grad(): 
        val_correct = 0
        val_total = 0
        val_loss = 0
        for data in val_loader:
            images, val_labels = data[0].to(device), data[1].to(device)
            images = images.to(device)
            val_labels = val_labels.to(device)
            outputs = mobilenetV2(images)
            lossVal = criterion(outputs,val_labels)
            val_loss += lossVal.item()
            # Validation set accuracy
            
            _,predicted = torch.max(outputs.data, 1)
            val_correct += (predicted == val_labels).sum().item()
            val_total  += val_labels.size(0)
          
        validation_accuracy = (val_correct / val_total) *100

    scheduler.step()  
    epoch_loss = running_loss/len(train_loader)
    val_loss = val_loss/len(val_loader)
    epoch_accuracy = 100.00 * running_correct/total
    Accuracies.append(epoch_accuracy)
    valAccuracies.append(validation_accuracy)
    trainLoss.append(epoch_loss)
    valLoss.append(val_loss)
    
    print("Training Data: Epoch Loss: %.3f, Epoch Accuracy: %.3f, Validation Loss: %.3f"%(epoch_loss,epoch_accuracy,val_loss))

print("---Training finished in {} seconds---".format(time.time()-t1))
epoch_count+=n_epochs
torch.save(mobilenetV2.state_dict(), "/content/5-Class-"+str(epoch_count)+"-epoch.pt")

test_acc = evaluate_model(mobilenetV2,test_loader)
dict = {'Training': Accuracies, 'Validation': valAccuracies} 
dictLoss = {'Training': trainLoss,'Validation': valLoss}
df = pd.DataFrame(dict)
df2 = pd.DataFrame(dictLoss)
df.to_csv("/content/Accuracies"+str(epoch_count)+".csv")
df2.to_csv("/content/Loss"+str(epoch_count)+".csv")
files.download("/content/5-Class-"+str(epoch_count)+"-epoch.pt")
files.download("/content/Accuracies"+str(epoch_count)+".csv")
files.download("/content/Loss"+str(epoch_count)+".csv")
# Out:
# Epoch number 1
# Training Data: Epoch Loss: 1.597, Epoch Accuracy: 24.193, Validation Loss: 1.584
# Epoch number 2
# Training Data: Epoch Loss: 1.574, Epoch Accuracy: 27.110, Validation Loss: 1.566
# Epoch number 3
# Training Data: Epoch Loss: 1.550, Epoch Accuracy: 29.099, Validation Loss: 1.547
# Epoch number 4
# Training Data: Epoch Loss: 1.510, Epoch Accuracy: 32.254, Validation Loss: 1.523
# Epoch number 5
# Training Data: Epoch Loss: 1.471, Epoch Accuracy: 35.254, Validation Loss: 1.452
# Epoch number 6
# Training Data: Epoch Loss: 1.442, Epoch Accuracy: 36.741, Validation Loss: 1.428
# Epoch number 7
# Training Data: Epoch Loss: 1.411, Epoch Accuracy: 38.820, Validation Loss: 1.406
# Epoch number 8
# Training Data: Epoch Loss: 1.374, Epoch Accuracy: 41.910, Validation Loss: 1.373
# Epoch number 9
# Training Data: Epoch Loss: 1.334, Epoch Accuracy: 43.726, Validation Loss: 1.338
# Epoch number 10
# Training Data: Epoch Loss: 1.307, Epoch Accuracy: 44.860, Validation Loss: 1.315
# Epoch number 11
# Training Data: Epoch Loss: 1.289, Epoch Accuracy: 45.928, Validation Loss: 1.304
# Epoch number 12
# Training Data: Epoch Loss: 1.263, Epoch Accuracy: 47.235, Validation Loss: 1.258
# Epoch number 13
# Training Data: Epoch Loss: 1.241, Epoch Accuracy: 48.698, Validation Loss: 1.228
# Epoch number 14
# Training Data: Epoch Loss: 1.223, Epoch Accuracy: 48.977, Validation Loss: 1.201
# Epoch number 15
# Training Data: Epoch Loss: 1.202, Epoch Accuracy: 50.390, Validation Loss: 1.179
# Epoch number 16
# Training Data: Epoch Loss: 1.188, Epoch Accuracy: 51.220, Validation Loss: 1.179
# Epoch number 17
# Training Data: Epoch Loss: 1.171, Epoch Accuracy: 51.845, Validation Loss: 1.169
# Epoch number 18
# Training Data: Epoch Loss: 1.158, Epoch Accuracy: 52.773, Validation Loss: 1.139
# Epoch number 19
# Training Data: Epoch Loss: 1.141, Epoch Accuracy: 53.554, Validation Loss: 1.137
# Epoch number 20
# Training Data: Epoch Loss: 1.133, Epoch Accuracy: 53.751, Validation Loss: 1.131
# Epoch number 21
# Training Data: Epoch Loss: 1.117, Epoch Accuracy: 54.491, Validation Loss: 1.150
# Epoch number 22
# Training Data: Epoch Loss: 1.113, Epoch Accuracy: 54.894, Validation Loss: 1.082
# Epoch number 23
# Training Data: Epoch Loss: 1.087, Epoch Accuracy: 55.641, Validation Loss: 1.068
# Epoch number 24
# Training Data: Epoch Loss: 1.090, Epoch Accuracy: 55.855, Validation Loss: 1.072
# Epoch number 25
# Training Data: Epoch Loss: 1.072, Epoch Accuracy: 56.792, Validation Loss: 1.053
# Epoch number 26
# Training Data: Epoch Loss: 1.057, Epoch Accuracy: 57.178, Validation Loss: 1.039
# Epoch number 27
# Training Data: Epoch Loss: 1.051, Epoch Accuracy: 57.507, Validation Loss: 1.029
# Epoch number 28
# Training Data: Epoch Loss: 1.047, Epoch Accuracy: 57.581, Validation Loss: 1.001
# Epoch number 29
# Training Data: Epoch Loss: 1.031, Epoch Accuracy: 58.756, Validation Loss: 1.001
# Epoch number 30
# Training Data: Epoch Loss: 1.020, Epoch Accuracy: 59.241, Validation Loss: 1.006
# Epoch number 31
# Training Data: Epoch Loss: 1.019, Epoch Accuracy: 58.854, Validation Loss: 0.986
# Epoch number 32
# Training Data: Epoch Loss: 1.000, Epoch Accuracy: 60.523, Validation Loss: 0.996
# Epoch number 33
# Training Data: Epoch Loss: 0.994, Epoch Accuracy: 60.178, Validation Loss: 0.987
# Epoch number 34
# Training Data: Epoch Loss: 0.972, Epoch Accuracy: 61.180, Validation Loss: 0.980
# Epoch number 35
# Training Data: Epoch Loss: 0.972, Epoch Accuracy: 61.714, Validation Loss: 0.952
# Epoch number 36
# Training Data: Epoch Loss: 0.964, Epoch Accuracy: 62.018, Validation Loss: 0.983
# Epoch number 37
# Training Data: Epoch Loss: 0.948, Epoch Accuracy: 62.355, Validation Loss: 0.965
# Epoch number 38
# Training Data: Epoch Loss: 0.950, Epoch Accuracy: 62.462, Validation Loss: 0.960
# Epoch number 39
# Training Data: Epoch Loss: 0.949, Epoch Accuracy: 62.799, Validation Loss: 0.909
# Epoch number 40
# Training Data: Epoch Loss: 0.922, Epoch Accuracy: 63.908, Validation Loss: 0.911
# Epoch number 41
# Training Data: Epoch Loss: 0.916, Epoch Accuracy: 63.843, Validation Loss: 0.932
# Epoch number 42
# Training Data: Epoch Loss: 0.905, Epoch Accuracy: 64.212, Validation Loss: 0.900
# Epoch number 43
# Training Data: Epoch Loss: 0.901, Epoch Accuracy: 64.574, Validation Loss: 0.871
# Epoch number 44
# Training Data: Epoch Loss: 0.879, Epoch Accuracy: 65.371, Validation Loss: 0.868
# Epoch number 45
# Training Data: Epoch Loss: 0.870, Epoch Accuracy: 65.872, Validation Loss: 0.931
# Epoch number 46
# Training Data: Epoch Loss: 0.866, Epoch Accuracy: 66.053, Validation Loss: 0.844
# Epoch number 47
# Training Data: Epoch Loss: 0.857, Epoch Accuracy: 66.390, Validation Loss: 0.854
# Epoch number 48
# Training Data: Epoch Loss: 0.847, Epoch Accuracy: 67.138, Validation Loss: 0.849
# Epoch number 49
# Training Data: Epoch Loss: 0.831, Epoch Accuracy: 67.409, Validation Loss: 0.834
# Epoch number 50
# Training Data: Epoch Loss: 0.827, Epoch Accuracy: 67.409, Validation Loss: 0.848
# Epoch number 51
# Training Data: Epoch Loss: 0.816, Epoch Accuracy: 68.173, Validation Loss: 0.822
# Epoch number 52
# Training Data: Epoch Loss: 0.805, Epoch Accuracy: 68.272, Validation Loss: 0.829
# Epoch number 53
# Training Data: Epoch Loss: 0.802, Epoch Accuracy: 68.814, Validation Loss: 0.818
# Epoch number 54
# Training Data: Epoch Loss: 0.780, Epoch Accuracy: 69.866, Validation Loss: 0.803
# Epoch number 55
# Training Data: Epoch Loss: 0.780, Epoch Accuracy: 69.603, Validation Loss: 0.795
# Epoch number 56
# Training Data: Epoch Loss: 0.771, Epoch Accuracy: 70.030, Validation Loss: 0.796
# Epoch number 57
# Training Data: Epoch Loss: 0.775, Epoch Accuracy: 70.351, Validation Loss: 0.793
# Epoch number 58
# Training Data: Epoch Loss: 0.763, Epoch Accuracy: 70.639, Validation Loss: 0.793
# Epoch number 59
# Training Data: Epoch Loss: 0.764, Epoch Accuracy: 70.269, Validation Loss: 0.789
# Epoch number 60
# Training Data: Epoch Loss: 0.758, Epoch Accuracy: 70.655, Validation Loss: 0.777
# Epoch number 61
# Training Data: Epoch Loss: 0.760, Epoch Accuracy: 70.425, Validation Loss: 0.766
# Epoch number 62
# Training Data: Epoch Loss: 0.732, Epoch Accuracy: 71.879, Validation Loss: 0.775
# Epoch number 63
# Training Data: Epoch Loss: 0.737, Epoch Accuracy: 71.271, Validation Loss: 0.761
# Epoch number 64
# Training Data: Epoch Loss: 0.739, Epoch Accuracy: 71.608, Validation Loss: 0.772
# Epoch number 65
# Training Data: Epoch Loss: 0.728, Epoch Accuracy: 71.814, Validation Loss: 0.778
# Epoch number 66
# Training Data: Epoch Loss: 0.727, Epoch Accuracy: 71.920, Validation Loss: 0.775
# Epoch number 67
# Training Data: Epoch Loss: 0.722, Epoch Accuracy: 72.068, Validation Loss: 0.767
# Epoch number 68
# Training Data: Epoch Loss: 0.720, Epoch Accuracy: 72.175, Validation Loss: 0.781
# Epoch number 69
# Training Data: Epoch Loss: 0.732, Epoch Accuracy: 71.411, Validation Loss: 0.774
# Epoch number 70
# Training Data: Epoch Loss: 0.719, Epoch Accuracy: 72.644, Validation Loss: 0.770
# Epoch number 71
# Training Data: Epoch Loss: 0.715, Epoch Accuracy: 72.298, Validation Loss: 0.761
# Epoch number 72
# Training Data: Epoch Loss: 0.719, Epoch Accuracy: 72.068, Validation Loss: 0.792
# Epoch number 73
# Training Data: Epoch Loss: 0.706, Epoch Accuracy: 72.874, Validation Loss: 0.754
# Epoch number 74
# Training Data: Epoch Loss: 0.705, Epoch Accuracy: 72.824, Validation Loss: 0.762
# Epoch number 75
# Training Data: Epoch Loss: 0.698, Epoch Accuracy: 72.890, Validation Loss: 0.777
# Epoch number 76
# Training Data: Epoch Loss: 0.709, Epoch Accuracy: 72.964, Validation Loss: 0.772
# Epoch number 77
# Training Data: Epoch Loss: 0.696, Epoch Accuracy: 73.391, Validation Loss: 0.773
# Epoch number 78
# Training Data: Epoch Loss: 0.694, Epoch Accuracy: 73.211, Validation Loss: 0.766
# Epoch number 79
# Training Data: Epoch Loss: 0.709, Epoch Accuracy: 72.816, Validation Loss: 0.755
# Epoch number 80
# Training Data: Epoch Loss: 0.678, Epoch Accuracy: 73.523, Validation Loss: 0.750
# Epoch number 81
# Training Data: Epoch Loss: 0.665, Epoch Accuracy: 74.451, Validation Loss: 0.768
# Epoch number 82
# Training Data: Epoch Loss: 0.677, Epoch Accuracy: 73.917, Validation Loss: 0.754
# Epoch number 83
# Training Data: Epoch Loss: 0.672, Epoch Accuracy: 74.345, Validation Loss: 0.804
# Epoch number 84
# Training Data: Epoch Loss: 0.666, Epoch Accuracy: 74.123, Validation Loss: 0.726
# Epoch number 85
# Training Data: Epoch Loss: 0.647, Epoch Accuracy: 75.249, Validation Loss: 0.746
# Epoch number 86
# Training Data: Epoch Loss: 0.645, Epoch Accuracy: 75.249, Validation Loss: 0.754
# Epoch number 87
# Training Data: Epoch Loss: 0.632, Epoch Accuracy: 75.758, Validation Loss: 0.756
# Epoch number 88
# Training Data: Epoch Loss: 0.636, Epoch Accuracy: 75.964, Validation Loss: 0.723
# Epoch number 89
# Training Data: Epoch Loss: 0.620, Epoch Accuracy: 76.300, Validation Loss: 0.724
# Epoch number 90
# Training Data: Epoch Loss: 0.616, Epoch Accuracy: 76.202, Validation Loss: 0.728
# Epoch number 91
# Training Data: Epoch Loss: 0.618, Epoch Accuracy: 76.300, Validation Loss: 0.730
# Epoch number 92
# Training Data: Epoch Loss: 0.598, Epoch Accuracy: 77.237, Validation Loss: 0.735
# Epoch number 93
# Training Data: Epoch Loss: 0.593, Epoch Accuracy: 77.484, Validation Loss: 0.716
# Epoch number 94
# Training Data: Epoch Loss: 0.593, Epoch Accuracy: 77.467, Validation Loss: 0.736
# Epoch number 95
# Training Data: Epoch Loss: 0.584, Epoch Accuracy: 77.467, Validation Loss: 0.722
# Epoch number 96
# Training Data: Epoch Loss: 0.582, Epoch Accuracy: 77.623, Validation Loss: 0.712
# Epoch number 97
# Training Data: Epoch Loss: 0.575, Epoch Accuracy: 77.919, Validation Loss: 0.726
# Epoch number 98
# Training Data: Epoch Loss: 0.570, Epoch Accuracy: 78.174, Validation Loss: 0.726
# Epoch number 99
# Training Data: Epoch Loss: 0.560, Epoch Accuracy: 78.264, Validation Loss: 0.709
# Epoch number 100
# Training Data: Epoch Loss: 0.550, Epoch Accuracy: 78.938, Validation Loss: 0.721
# ---Training finished in 12719.250771284103 seconds---
# Testing Data: Epoch Accuracy: 73.796

# %%
print(val_loss/len(val_loader))
# Out:
# 0.006611968360307612

# %%
# Plotting Accuracies Vs Epochs
plt.plot(range(n_epochs),Accuracies)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracies")
plt.title("Training Accuracy Vs Epochs")
plt.show()

# %%
# Plotting Validation Accuracies Vs Train Accuracies on Epochs
plt.plot(range(n_epochs),Accuracies, label="Training")
plt.plot(range(n_epochs),valAccuracies, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracies") 
plt.title("Training vs Validation Accuracies")
plt.legend()
plt.show()

# %%
# Plotting Validation Accuracies Vs Train Accuracies on Epochs
plt.plot(range(n_epochs),trainLoss, label="Training")
plt.plot(range(n_epochs),valLoss, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

# %%
#Calculate Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []

# iterate over test data
for data in test_loader:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = mobilenetV2(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = (0,1,2,3,4)

# Build confusion matrix
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),display_labels=classes)
fig,ax = plt.subplots()
fig.set_size_inches(13,13)
plt.title("Confusion Matrix mobilenet V2 (5-Classes)")
disp.plot(ax=ax)
plt.show()

# %%
#Precision Calculation and Recall calculation
from sklearn.metrics import precision_score, recall_score,f1_score

print("Precision Macro:{:.2f}".format(precision_score(y_true, y_pred, average='macro')))
print("Precision Micro:{:.2f}".format(precision_score(y_true,y_pred,average='micro')))
print("Recall Macro:{:.2f}".format(recall_score(y_true,y_pred,average='macro')))
print("Recall Micro:{:.2f}".format(recall_score(y_true,y_pred,average='micro')))
print("F1-Score Macro:{:.2f}".format(f1_score(y_true,y_pred,average='macro')))
print("F1-Score Micro:{:.2f}".format(f1_score(y_true,y_pred,average='micro')))
# Out:
# Precision Macro:0.74
# Precision Micro:0.74
# Recall Macro:0.73
# Recall Micro:0.74
# F1-Score Macro:0.74
# F1-Score Micro:0.74
