# %%
import torch.nn as nn
import torch
import torchvision.transforms as transforms
from torchsummary import summary
import torchvision
import time
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import os
from google.colab import files
from google.colab import drive

# %%
drive.mount('/content/drive')
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/5-class.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')

picture = plt.imread('/content/5-class/preprocessed-cleaned-set/train/class-1/00056e9548477cda7a885bb423cb668c.jpg')
imageShow = plt.imshow(picture)
# Out:
# Mounted at /content/drive
# Done

# %%
resnet18Model = models.resnet18(pretrained=False, num_classes=5)
num_filters = resnet18Model.fc.in_features
num_classes = 5 
resnet18Model.fc = nn.Linear(num_filters,num_classes)
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameters(resnet18Model)
# summary(resnet18Model,input_size=(3,324,324))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
resnet18Model.to(device)
print("Device: {}".format(device))
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet18Model.parameters(), lr=0.0002,momentum=0.9)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=0.0001)
n_epochs = 100
epoch_count = 0
# resnet18Model.load_state_dict(torch.load('/content/82-epoch-output.pt'))
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Device: cuda:0

# %%
#import this file to train models and pass the  name of the datset
# extract zip files
# load the images and labels based on the dataset requested
# do the pre-processing , batch normalization , flip etc

# Transofrmations for preprocessedSnakeImages dataset
# Reference from https://www.youtube.com/watch?v=z3kB3ISIPAg&list=PL3Dh_99BJkCEhE7Ri8W6aijiEqm3ZoGRq&index=4
training_path = '/content/5-class/preprocessed-cleaned-set/train/'
test_path = '/content/5-class/preprocessed-cleaned-set/test'
val_path = '/content/5-class/preprocessed-cleaned-set/val'
def transformDS1( batchSize, inputSize):

    training_transforms = transforms.Compose([transforms.Resize((inputSize,inputSize)),transforms.ToTensor()])
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform = training_transforms)
    train_Loader = torch.utils.data.DataLoader(dataset = train_dataset,batch_size=batchSize,shuffle=False)
    mean, std = get_mean_std(train_Loader)
    train_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    test_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])

    val_transforms = transforms.Compose([
        transforms.Resize((inputSize,inputSize)),
        transforms.ToTensor(),
        transforms.Normalize(torch.Tensor(mean),torch.Tensor(std))
    ])
    
    train_dataset = torchvision.datasets.ImageFolder(root=training_path,transform=train_transforms)
    test_dataset = torchvision.datasets.ImageFolder(root=test_path,transform=test_transforms)
    val_dataset = torchvision.datasets.ImageFolder(root=val_path,transform=val_transforms)

    data_loader_train = torch.utils.data.DataLoader(train_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_test = torch.utils.data.DataLoader(test_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)
    data_loader_val = torch.utils.data.DataLoader(val_dataset, batch_size=batchSize,
    shuffle=True,drop_last=False,num_workers=0)

    return data_loader_train,data_loader_test,data_loader_val

def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images_count = 0
    for images,_ in loader:
        images_count_in_batch = images.size(0)
        images =images.view(images_count_in_batch,images.size(1),-1)
        mean+=images.mean(2).sum(0)
        std+=images.std(2).sum(0)
        total_images_count+=images_count_in_batch
    mean /= total_images_count
    std /= total_images_count
    return mean,std

def show_transformed_images(data_loader_train):
    batch=next(iter(data_loader_train))
    images,labels = batch
    grid = torchvision.utils.make_grid(images,nrow=3)
    plt.figure(figsize=(11,11))
    plt.imshow(np.transpose(grid,(1,2,0)))
    plt.show()
    print("labels:",labels)

# %%
def evaluate_model(model,test_loader):
    model.eval()
    predicted_correct =0
    total = 0
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            images = images.to(device)
            labels = labels.to(device)
            total+=labels.size(0)
            outputs = model(images)
            _,predicted = torch.max(outputs,1)
            predicted_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100.0* predicted_correct/total
    print("Testing Data: Epoch Accuracy: %.3f"%(epoch_accuracy))
    return epoch_accuracy

# %%
train_loader,test_loader,val_loader = transformDS1(32,224)
show_transformed_images(val_loader)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels: tensor([4, 0, 4, 4, 0, 3, 1, 3, 3, 4, 2, 3, 4, 1, 2, 4, 2, 3, 3, 3, 2, 0, 2, 3,
#         1, 4, 4, 4, 2, 0, 0, 0])

# %%
Accuracies = [] 
valAccuracies = []
valLoss = []
trainLoss = []
total_steps = len(train_loader)
t1 = time.time()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
validation_accuracy = 0
# print("-----Device:"+device+"-----")
for epoch in range(n_epochs):
    print("Epoch number %d" %(epoch+1))
    resnet18Model.train()
    running_loss = 0.0
    running_correct = 0.0
    val_loss = 0.0
    total = 0
    for i, data in enumerate(train_loader):
      images,labels = data
      device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
      images = images.to(device)
      labels = labels.to(device)
      total+=labels.size(0)

      optimizer.zero_grad()
      outputs = resnet18Model(images)
      _,predicted = torch.max(outputs.data,1)
      loss = criterion(outputs,labels)
      loss.backward()
      optimizer.step()
      
      running_loss+=loss.item()
      running_correct += (labels==predicted).sum().item()
     
      
      training_accuracy = (running_correct / total) * 100
    validation_accuracy = 0
    resnet18Model.eval()
    with torch.no_grad(): 
        val_correct = 0
        val_total = 0
        val_loss = 0
        for data in val_loader:
            images, val_labels = data[0].to(device), data[1].to(device)
            images = images.to(device)
            val_labels = val_labels.to(device)
            outputs = resnet18Model(images)
            lossVal = criterion(outputs,val_labels)
            val_loss += lossVal.item()
            # Validation set accuracy
            
            _,predicted = torch.max(outputs.data, 1)
            val_correct += (predicted == val_labels).sum().item()
            val_total  += val_labels.size(0)
          
        validation_accuracy = (val_correct / val_total) *100

    scheduler.step()  
    epoch_loss = running_loss/len(train_loader)
    val_loss = val_loss/len(val_loader)
    epoch_accuracy = 100.00 * running_correct/total
    Accuracies.append(epoch_accuracy)
    valAccuracies.append(validation_accuracy)
    trainLoss.append(epoch_loss)
    valLoss.append(val_loss)
    
    print("Training Data: Epoch Loss: %.3f, Epoch Accuracy: %.3f, Validation Loss: %.3f"%(epoch_loss,epoch_accuracy,val_loss))

print("---Training finished in {} seconds---".format(time.time()-t1))
epoch_count+=n_epochs
torch.save(resnet18Model.state_dict(), "/content/5-Class-"+str(epoch_count)+"-epoch.pt")

test_acc = evaluate_model(resnet18Model,test_loader)
dict = {'Training': Accuracies, 'Validation': valAccuracies} 
dictLoss = {'Training': trainLoss,'Validation': valLoss}
df = pd.DataFrame(dict)
df2 = pd.DataFrame(dictLoss)
df.to_csv("/content/Accuracies"+str(epoch_count)+".csv")
df2.to_csv("/content/Loss"+str(epoch_count)+".csv")
files.download("/content/5-Class-"+str(epoch_count)+"-epoch.pt")
files.download("/content/Accuracies"+str(epoch_count)+".csv")
files.download("/content/Loss"+str(epoch_count)+".csv")
# Out:
# Epoch number 1
# Training Data: Epoch Loss: 1.557, Epoch Accuracy: 29.518, Validation Loss: 1.497
# Epoch number 2
# Training Data: Epoch Loss: 1.457, Epoch Accuracy: 37.004, Validation Loss: 1.437
# Epoch number 3
# Training Data: Epoch Loss: 1.402, Epoch Accuracy: 40.085, Validation Loss: 1.376
# Epoch number 4
# Training Data: Epoch Loss: 1.364, Epoch Accuracy: 41.811, Validation Loss: 1.381
# Epoch number 5
# Training Data: Epoch Loss: 1.331, Epoch Accuracy: 44.186, Validation Loss: 1.311
# Epoch number 6
# Training Data: Epoch Loss: 1.285, Epoch Accuracy: 46.454, Validation Loss: 1.249
# Epoch number 7
# Training Data: Epoch Loss: 1.247, Epoch Accuracy: 48.525, Validation Loss: 1.248
# Epoch number 8
# Training Data: Epoch Loss: 1.223, Epoch Accuracy: 49.700, Validation Loss: 1.197
# Epoch number 9
# Training Data: Epoch Loss: 1.188, Epoch Accuracy: 51.393, Validation Loss: 1.255
# Epoch number 10
# Training Data: Epoch Loss: 1.163, Epoch Accuracy: 52.815, Validation Loss: 1.130
# Epoch number 11
# Training Data: Epoch Loss: 1.147, Epoch Accuracy: 53.801, Validation Loss: 1.129
# Epoch number 12
# Training Data: Epoch Loss: 1.119, Epoch Accuracy: 54.861, Validation Loss: 1.093
# Epoch number 13
# Training Data: Epoch Loss: 1.095, Epoch Accuracy: 55.682, Validation Loss: 1.125
# Epoch number 14
# Training Data: Epoch Loss: 1.082, Epoch Accuracy: 56.948, Validation Loss: 1.163
# Epoch number 15
# Training Data: Epoch Loss: 1.061, Epoch Accuracy: 57.466, Validation Loss: 1.143
# Epoch number 16
# Training Data: Epoch Loss: 1.045, Epoch Accuracy: 58.518, Validation Loss: 1.054
# Epoch number 17
# Training Data: Epoch Loss: 1.032, Epoch Accuracy: 59.183, Validation Loss: 1.076
# Epoch number 18
# Training Data: Epoch Loss: 1.016, Epoch Accuracy: 59.791, Validation Loss: 1.153
# Epoch number 19
# Training Data: Epoch Loss: 1.001, Epoch Accuracy: 60.572, Validation Loss: 1.042
# Epoch number 20
# Training Data: Epoch Loss: 0.983, Epoch Accuracy: 61.188, Validation Loss: 1.013
# Epoch number 21
# Training Data: Epoch Loss: 0.979, Epoch Accuracy: 61.336, Validation Loss: 1.126
# Epoch number 22
# Training Data: Epoch Loss: 0.968, Epoch Accuracy: 62.035, Validation Loss: 0.984
# Epoch number 23
# Training Data: Epoch Loss: 0.953, Epoch Accuracy: 62.240, Validation Loss: 1.003
# Epoch number 24
# Training Data: Epoch Loss: 0.946, Epoch Accuracy: 63.029, Validation Loss: 0.967
# Epoch number 25
# Training Data: Epoch Loss: 0.930, Epoch Accuracy: 63.440, Validation Loss: 1.111
# Epoch number 26
# Training Data: Epoch Loss: 0.929, Epoch Accuracy: 63.736, Validation Loss: 1.090
# Epoch number 27
# Training Data: Epoch Loss: 0.910, Epoch Accuracy: 64.385, Validation Loss: 0.942
# Epoch number 28
# Training Data: Epoch Loss: 0.906, Epoch Accuracy: 64.894, Validation Loss: 1.032
# Epoch number 29
# Training Data: Epoch Loss: 0.887, Epoch Accuracy: 65.470, Validation Loss: 0.997
# Epoch number 30
# Training Data: Epoch Loss: 0.875, Epoch Accuracy: 66.012, Validation Loss: 0.928
# Epoch number 31
# Training Data: Epoch Loss: 0.879, Epoch Accuracy: 65.667, Validation Loss: 0.881
# Epoch number 32
# Training Data: Epoch Loss: 0.865, Epoch Accuracy: 66.176, Validation Loss: 1.044
# Epoch number 33
# Training Data: Epoch Loss: 0.853, Epoch Accuracy: 66.899, Validation Loss: 0.903
# Epoch number 34
# Training Data: Epoch Loss: 0.848, Epoch Accuracy: 66.982, Validation Loss: 0.909
# Epoch number 35
# Training Data: Epoch Loss: 0.834, Epoch Accuracy: 67.549, Validation Loss: 0.944
# Epoch number 36
# Training Data: Epoch Loss: 0.818, Epoch Accuracy: 68.272, Validation Loss: 1.046
# Epoch number 37
# Training Data: Epoch Loss: 0.816, Epoch Accuracy: 68.280, Validation Loss: 0.882
# Epoch number 38
# Training Data: Epoch Loss: 0.810, Epoch Accuracy: 68.748, Validation Loss: 1.083
# Epoch number 39
# Training Data: Epoch Loss: 0.787, Epoch Accuracy: 69.669, Validation Loss: 0.856
# Epoch number 40
# Training Data: Epoch Loss: 0.770, Epoch Accuracy: 70.589, Validation Loss: 0.827
# Epoch number 41
# Training Data: Epoch Loss: 0.769, Epoch Accuracy: 70.622, Validation Loss: 0.815
# Epoch number 42
# Training Data: Epoch Loss: 0.750, Epoch Accuracy: 70.984, Validation Loss: 1.320
# Epoch number 43
# Training Data: Epoch Loss: 0.750, Epoch Accuracy: 71.132, Validation Loss: 0.835
# Epoch number 44
# Training Data: Epoch Loss: 0.742, Epoch Accuracy: 71.551, Validation Loss: 0.981
# Epoch number 45
# Training Data: Epoch Loss: 0.723, Epoch Accuracy: 72.167, Validation Loss: 0.806
# Epoch number 46
# Training Data: Epoch Loss: 0.714, Epoch Accuracy: 73.153, Validation Loss: 0.923
# Epoch number 47
# Training Data: Epoch Loss: 0.699, Epoch Accuracy: 73.309, Validation Loss: 0.883
# Epoch number 48
# Training Data: Epoch Loss: 0.689, Epoch Accuracy: 73.975, Validation Loss: 0.813
# Epoch number 49
# Training Data: Epoch Loss: 0.684, Epoch Accuracy: 73.983, Validation Loss: 0.769
# Epoch number 50
# Training Data: Epoch Loss: 0.680, Epoch Accuracy: 74.156, Validation Loss: 0.747
# Epoch number 51
# Training Data: Epoch Loss: 0.658, Epoch Accuracy: 75.347, Validation Loss: 0.776
# Epoch number 52
# Training Data: Epoch Loss: 0.649, Epoch Accuracy: 75.166, Validation Loss: 0.762
# Epoch number 53
# Training Data: Epoch Loss: 0.649, Epoch Accuracy: 75.018, Validation Loss: 0.775
# Epoch number 54
# Training Data: Epoch Loss: 0.636, Epoch Accuracy: 76.177, Validation Loss: 0.735
# Epoch number 55
# Training Data: Epoch Loss: 0.622, Epoch Accuracy: 76.621, Validation Loss: 0.753
# Epoch number 56
# Training Data: Epoch Loss: 0.617, Epoch Accuracy: 76.769, Validation Loss: 0.882
# Epoch number 57
# Training Data: Epoch Loss: 0.616, Epoch Accuracy: 76.835, Validation Loss: 0.752
# Epoch number 58
# Training Data: Epoch Loss: 0.606, Epoch Accuracy: 77.081, Validation Loss: 0.767
# Epoch number 59
# Training Data: Epoch Loss: 0.598, Epoch Accuracy: 77.328, Validation Loss: 0.764
# Epoch number 60
# Training Data: Epoch Loss: 0.601, Epoch Accuracy: 76.900, Validation Loss: 0.745
# Epoch number 61
# Training Data: Epoch Loss: 0.591, Epoch Accuracy: 78.470, Validation Loss: 0.739
# Epoch number 62
# Training Data: Epoch Loss: 0.593, Epoch Accuracy: 77.566, Validation Loss: 0.681
# Epoch number 63
# Training Data: Epoch Loss: 0.584, Epoch Accuracy: 78.240, Validation Loss: 0.805
# Epoch number 64
# Training Data: Epoch Loss: 0.583, Epoch Accuracy: 78.059, Validation Loss: 0.704
# Epoch number 65
# Training Data: Epoch Loss: 0.585, Epoch Accuracy: 77.993, Validation Loss: 0.692
# Epoch number 66
# Training Data: Epoch Loss: 0.573, Epoch Accuracy: 78.470, Validation Loss: 0.733
# Epoch number 67
# Training Data: Epoch Loss: 0.566, Epoch Accuracy: 78.503, Validation Loss: 0.761
# Epoch number 68
# Training Data: Epoch Loss: 0.583, Epoch Accuracy: 78.248, Validation Loss: 0.762
# Epoch number 69
# Training Data: Epoch Loss: 0.571, Epoch Accuracy: 78.659, Validation Loss: 0.762
# Epoch number 70
# Training Data: Epoch Loss: 0.578, Epoch Accuracy: 78.379, Validation Loss: 0.830
# Epoch number 71
# Training Data: Epoch Loss: 0.568, Epoch Accuracy: 78.601, Validation Loss: 0.741
# Epoch number 72
# Training Data: Epoch Loss: 0.564, Epoch Accuracy: 79.209, Validation Loss: 0.818
# Epoch number 73
# Training Data: Epoch Loss: 0.563, Epoch Accuracy: 78.511, Validation Loss: 0.806
# Epoch number 74
# Training Data: Epoch Loss: 0.566, Epoch Accuracy: 78.651, Validation Loss: 0.771
# Epoch number 75
# Training Data: Epoch Loss: 0.562, Epoch Accuracy: 78.947, Validation Loss: 0.718
# Epoch number 76
# Training Data: Epoch Loss: 0.565, Epoch Accuracy: 78.626, Validation Loss: 1.181
# Epoch number 77
# Training Data: Epoch Loss: 0.548, Epoch Accuracy: 79.407, Validation Loss: 0.818
# Epoch number 78
# Training Data: Epoch Loss: 0.560, Epoch Accuracy: 78.930, Validation Loss: 1.044
# Epoch number 79
# Training Data: Epoch Loss: 0.545, Epoch Accuracy: 79.678, Validation Loss: 0.710
# Epoch number 80
# Training Data: Epoch Loss: 0.536, Epoch Accuracy: 79.883, Validation Loss: 0.984
# Epoch number 81
# Training Data: Epoch Loss: 0.533, Epoch Accuracy: 80.072, Validation Loss: 0.832
# Epoch number 82
# Training Data: Epoch Loss: 0.523, Epoch Accuracy: 80.434, Validation Loss: 1.052
# Epoch number 83
# Training Data: Epoch Loss: 0.522, Epoch Accuracy: 80.278, Validation Loss: 0.767
# Epoch number 84
# Training Data: Epoch Loss: 0.508, Epoch Accuracy: 81.157, Validation Loss: 0.756
# Epoch number 85
# Training Data: Epoch Loss: 0.499, Epoch Accuracy: 81.502, Validation Loss: 0.883
# Epoch number 86
# Training Data: Epoch Loss: 0.501, Epoch Accuracy: 81.683, Validation Loss: 0.779
# Epoch number 87
# Training Data: Epoch Loss: 0.492, Epoch Accuracy: 82.028, Validation Loss: 0.806
# Epoch number 88
# Training Data: Epoch Loss: 0.476, Epoch Accuracy: 82.012, Validation Loss: 0.745
# Epoch number 89
# Training Data: Epoch Loss: 0.474, Epoch Accuracy: 82.316, Validation Loss: 0.727
# Epoch number 90
# Training Data: Epoch Loss: 0.478, Epoch Accuracy: 82.234, Validation Loss: 0.648
# Epoch number 91
# Training Data: Epoch Loss: 0.464, Epoch Accuracy: 82.669, Validation Loss: 0.772
# Epoch number 92
# Training Data: Epoch Loss: 0.444, Epoch Accuracy: 83.565, Validation Loss: 0.688
# Epoch number 93
# Training Data: Epoch Loss: 0.447, Epoch Accuracy: 83.195, Validation Loss: 0.662
# Epoch number 94
# Training Data: Epoch Loss: 0.431, Epoch Accuracy: 83.877, Validation Loss: 0.764
# Epoch number 95
# Training Data: Epoch Loss: 0.431, Epoch Accuracy: 84.206, Validation Loss: 0.649
# Epoch number 96
# Training Data: Epoch Loss: 0.417, Epoch Accuracy: 84.428, Validation Loss: 0.678
# Epoch number 97
# Training Data: Epoch Loss: 0.422, Epoch Accuracy: 84.608, Validation Loss: 0.696
# Epoch number 98
# Training Data: Epoch Loss: 0.407, Epoch Accuracy: 84.937, Validation Loss: 0.729
# Epoch number 99
# Training Data: Epoch Loss: 0.407, Epoch Accuracy: 85.101, Validation Loss: 0.682
# Epoch number 100
# Training Data: Epoch Loss: 0.402, Epoch Accuracy: 84.937, Validation Loss: 0.652
# ---Training finished in 12600.299983501434 seconds---
# Testing Data: Epoch Accuracy: 74.541

# %%
print(val_loss/len(val_loader))
# Out:
# 0.005984614860097444

# %%
# Plotting Accuracies Vs Epochs
plt.plot(range(n_epochs),Accuracies)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracies")
plt.title("Training Accuracy Vs Epochs")
plt.show()

# %%
# Plotting Validation Accuracies Vs Train Accuracies on Epochs
plt.plot(range(n_epochs),Accuracies, label="Training")
plt.plot(range(n_epochs),valAccuracies, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Training vs Validation Accuracies")
plt.legend()
plt.show()

# %%
# Plotting Validation Accuracies Vs Train Accuracies on Epochs
plt.plot(range(n_epochs),trainLoss, label="Training")
plt.plot(range(n_epochs),valLoss, label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

# %%
#Calculate Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []

# iterate over test data
for data in test_loader:
        inputs, labels = data[0].to(device), data[1].to(device)
        output = resnet18Model(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes
classes = (0,1,2,3,4)

# Build confusion matrix
confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred),display_labels=classes)
fig,ax = plt.subplots()
fig.set_size_inches(13,13)
plt.title("Confusion Matrix ResNet 18 (5-Classes)")
disp.plot(ax=ax)
plt.show()

# %%
#Precision Calculation and Recall calculation
from sklearn.metrics import precision_score, recall_score,f1_score

print("Precision Macro:{:.2f}".format(precision_score(y_true, y_pred, average='macro')))
print("Precision Micro:{:.2f}".format(precision_score(y_true,y_pred,average='micro')))
print("Recall Macro:{:.2f}".format(recall_score(y_true,y_pred,average='macro')))
print("Recall Micro:{:.2f}".format(recall_score(y_true,y_pred,average='micro')))
print("F1-Score Macro:{:.2f}".format(f1_score(y_true,y_pred,average='macro')))
print("F1-Score Micro:{:.2f}".format(f1_score(y_true,y_pred,average='micro')))
# Out:
# Precision Macro:0.74
# Precision Micro:0.75
# Recall Macro:0.74
# Recall Micro:0.75
# F1-Score Macro:0.74
# F1-Score Micro:0.75
